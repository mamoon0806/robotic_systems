# %% [markdown]
# <a href="https://colab.research.google.com/github/mamoon0806/robotic_systems/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def lspb(q0, q1, t, V):
  p = np.zeros(t.size)
  p_d = np.zeros(t.size)
  p_dd = np.zeros(t.size)


  t_0 = t[0]

  t_f = t[-1]

  t_b = (q0 - q1 + V * t_f)/V;
  a = V/t_b;

  for i in range(t.size):
    t_n = t[i]

    if t_n <= t_b:
      p[i] = q0 + a/2 * t_n**2
      p_d[i] = a*t_pn
      p_dd[i] = a

    elif t_n <= (t_f - t_b):
      p[i] = (q1 + q0 - V*t_f)/2 + V*t_n;
      p_d[i] = V;
      p_dd[i] = 0;

    else:
      p[i] = q1 - a/2 * t_f**2 + a*t_f*t_n - a/2*t_n**2;
      p_d[i] = a*t_f - a*t_n;
      p_dd[i] = -a;


  fig, axs = plt.subplots(3, 1)

  axs[0].plot(t, p)
  axs[0].set_title('Position vs time', pad=10)
  axs[1].plot(t, p_d)
  axs[1].set_title('Velocity vs time', pad=10)
  axs[2].plot(t, p_dd)
  axs[2].set_title('Acceleration vs time', pad=10)
  plt.tight_layout()

# %%
t = np.linspace(0, 1, 1000)

lspb(0, 40, t, 60)
